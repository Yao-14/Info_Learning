# %%
# %run human_play.py
# Out:
# Player 1 with X
# Player 2 with O
#
#        0       1       2       3       4       5       6       7
#
#    7   _       _       _       _       _       _       _       _
#
#
#    6   _       _       _       _       _       _       _       _
#
#
#    5   _       _       _       _       _       _       _       _
#
#
#    4   _       _       _       _       _       _       _       _
#
#
#    3   _       _       _       _       _       _       _       _
#
#
#    2   _       _       _       _       _       _       _       _
#
#
#    1   _       _       _       _       _       _       _       _
#
#
#    0   _       _       _       _       _       _       _       _
#
#
# Player 1 with X
# Player 2 with O
#
#        0       1       2       3       4       5       6       7
#
#    7   _       _       _       _       _       _       _       _
#
#
#    6   _       _       _       _       _       _       _       _
#
#
#    5   _       _       _       _       _       _       _       _
#
#
# ...
