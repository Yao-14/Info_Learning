# %%
#载入必要的包
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np



from keras.utils import np_utils, plot_model
from keras.models import Sequential
from keras.preprocessing.sequence import pad_sequences
from keras.layers import LSTM, Dense, Embedding, Dropout
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.
# D:\Users\Anaconda3\envs\env_cv\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# D:\Users\Anaconda3\envs\env_cv\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# D:\Users\Anaconda3\envs\env_cv\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# D:\Users\Anaconda3\envs\env_cv\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# D:\Users\Anaconda3\envs\env_cv\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# D:\Users\Anaconda3\envs\env_cv\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# 设置matplotlib绘图时的字体
from matplotlib import font_manager


my_font = font_manager.FontProperties(fname="/Library/Fonts/Songti.ttc")

# %%
# In[ ]: 读入数据

data = pd.read_csv('data.csv')

#查看数据
print(data.head())
# Out:
#                                           evaluation label
# 0                                    用了一段时间，感觉还不错，可以    正面
# 1  电视非常好，已经是家里的第二台了。第一天下单，第二天就到本地了，可是物流的人说车坏了，一直催...    正面
# 2                  电视比想象中的大好多，画面也很清晰，系统很智能，更多功能还在摸索中    正面
# 3                                                 不错    正面
# 4     用了这么多天了，感觉还不错。夏普的牌子还是比较可靠。希望以后比较耐用，现在是考量质量的时候。    正面

# %%
# In[ ]:查看有多少种评价

print(data.groupby('label')['label'].count())
# Out:
# label
# 正面    1908
# 负面    2375
# Name: label, dtype: int64

# %%
# 统计句子长度及长度出现的频数


data['length'] = data['evaluation'].apply(lambda x: len(x))
len_data = data.groupby('length').count()
length = len_data.index.tolist()
freq = len_data['evaluation'].tolist()
plt.bar(length, freq)
plt.xlabel("Sentences Length")
plt.ylabel("Frequency")
plt.show()

# %%
# 标签及词汇表
labels, vocabulary = list(data['label'].unique()), list(data['evaluation'].unique())

# 构造字符级别的特征
string = ''
for word in vocabulary:
        string += word

vocabulary = set(string)
    
print(vocabulary)
# Out:
# {'书', '碰', '暂', '忍', '捌', '症', '鉴', '痛', '余', '恳', '辑', 'o', '螺', '拨', '鸡', '叔', '微', '\uf604', '兴', '联', '尚', '丰', '淫', '浊', '图', '鯨', '呼', '品', '钱', '值', '鄙', '赚', '嚯', '池', '孔', '注', '炮', '寿', '高', '卸', '谁', '服', '铝', '虾', '载', '绕', '压', '玫', '挑', '救', '叭', '刀', '仇', '食', '黥', '真', '循', '京', '、', '□', '简', '官', '屋', '优', '暗', '蛮', '禁', '阜', '犊', '息', '习', '竞', '啥', '悄', '闲', '学', '进', '悠', '甲', '华', '爱', '娴', 'N', '氛', '踪', '柄', '哩', '继', '借', '”', '木', '噢', '厌', '感', '薄', '够', '诉', '饭', '浙', '掌', '尾', '搁', '崩', '鹰', '慌', '^', '原', '蒸', '吗', '博', '开', '日', '洞', '炒', '刷', '钟', '凑', '媒', '影', '示', '软', "'", '>', '骨', '残', '，', '虑', '绿', '屎', '统', '糟', '跤', '爸', '南', '扎', '太', '由', '流', '通', '歌', '挽', '\uf61c', '首', '裂', '》', '执', '同', '翻', '军', '瘪', '嘿', '费', '砂', '蛋', '弃', 'm', '碎', '亏', '单', '江', '淘', '差', '读', '苹', '壮', '玻', '最', '懂', '恰', '讨', '赢', '人', '瓦', '烂', '顺', '凌', '憾', '用', '捞', '今', '悍', '阶', '卓', '业', '较', '搪', '粒', '干', '午', '飞', '陋', 'k', '见', '描', '：', '豪', '交', '孑', '昏', '礼', '貌', '尘', '鸟', '脸', '⑨', '佛', '遇', '手', '节', '媳', '相', '揉', '再', '宁', '杜', '副', '浦', '吓', '罢', '办', '蓝', '零', '锈', '钻', 'U', '停', '绍', '買', '散', '括', '律', '算', '亮', '羡', '哦', '掏', '论', '渡', '7', '定', '波', '纳', '牌', '拭', '识', '窝', '虽', 'q', '贩', '锅', '壁', '花', '变', '辫', '杂', '者', '摇', '双', 'G', '馈', '仪', 'E', '授', '技', '它', '工', '稿', '反', '灯', '框', '致', '化', '掘', '案', '衔', '快', '愤', '鹅', 'g', '闸', '剧', '络', '秀', '竖', '烈', '厂', '適', '与', '层', '洁', '豫', '荣', '尽', '暖', '校', '序', '篮', '秋', '盛', '晓', '野', '布', '年', '康', '看', '五', '度', '挺', '迟', '象', '凡', '可', '村', '<', '主', '糙', '击', '况', '宝', '掉', '势', 'I', '改', '前', '千', '摩', '舌', '宅', '幕', '全', '點', '壹', '栽', '正', '福', '不', '叙', '婆', '怏', '购', '產', '丢', '呢', '科', '点', '模', '王', '窗', '望', '考', '呦', '突', '廉', '峰', '-', '射', '责', '早', '做', '克', '置', '回', '刑', '抚', '艾', '瑰', '赶', '为', '撰', '降', '起', '忠', '奏', '详', '他', '哪', '口', '吵', '灰', '娃', '城', '泥', '居', '困', '病', '以', '捷', '尔', '售', '舒', '非', '粥', '忑', '户', 'W', '佰', '季', '~', '列', '怪', '４', '坛', '班', '尝', '际', '普', '安', '末', '浓', '剔', '码', '境', '在', '疵', '。', '照', '撼', '镂', '产', '旋', '砖', '床', 'Q', '曰', '又', '儿', '匮', '于', '二', '拆', '霆', '增', '拿', '已', '妒', '完', '教', '毁', '基', '予', '耽', '默', '慧', '伟', '系', '游', '泪', '叹', '麻', '－', '歧', '現', '炸', '%', '跪', '知', '拗', '诚', '呐', '瑕', '核', '時', '拷', '团', '药', '免', '唱', '急', '海', '粘', '姓', '雾', '策', '乘', '明', '惜', '寨', '邮', '唤', '帖', '侯', '掰', '泛', '逼', '兔', '将', '包', '个', '姑', '惑', '李', '格', '握', '·', '慕', '头', '凶', '菜', '果', '奶', '县', '毫', '根', '慎', '刻', '槊', '局', '敲', '筒', '豆', '速', '摘', '立', '榔', '拍', '烁', '鲸', '任', '吭', '逾', '融', '"', '幅', '东', '５', '耳', '響', '源', '储', '传', '沟', '曲', '庭', '女', '晶', '娘', '彻', '坚', '哔', '晨', '受', '盆', '晃', '老', '忒', '焦', '胜', '桑', '錯', '慢', '偷', '腾', '退', '放', '醉', '聚', '般', '匀', '方', '朵', '劫', '泽', '规', 'b', '央', '站', '叉', '@', '询', '但', '激', '冒', '窄', '惊', '随', '山', '塞', '扑', '栓', '敏', '从', '错', '调', '茶', '脚', '尊', '欧', '畅', '隐', '枝', '割', '霸', '钮', '冤', '贼', '期', '分', '理', '建', '润', '着', '外', '岳', '铺', '赖', '碜', '水', '雅', '因', '母', '泡', '充', '确', '营', '架', '饱', '哀', '探', '级', '数', '互', '扇', '获', '引', '劣', '第', '寒', '钥', '熄', '喊', '右', '剩', '忽', '智', '陆', '溢', '件', '买', '承', '续', '\uf60d', '既', '州', '帐', '卡', '匆', '拦', '七', '会', '惨', '底', '饿', '缺', '卧', '证', '勿', '锤', '凹', '取', '趟', '星', '途', '断', '中', '秒', '/', '睹', '歪', '歉', '钝', '嘟', '偏', '哥', '除', '毛', '体', '逆', '尬', '稍', '代', '离', '猫', '宣', '岁', '没', '石', '笫', '答', '耍', '咯', '咬', '摄', '尴', '萌', '掛', '箱', '古', '擅', '专', '趴', '队', '坎', '听', '’', '勒', '抓', '斩', 'Δ', '乎', '信', '解', '过', '表', '史', '词', '衰', '妥', '大', '雙', '账', '兜', '松', '意', '8', '术', '土', '啃', '阔', '三', '下', '质', '沫', '喇', '关', '矣', '归', '权', '求', '约', '法', '而', '恢', '加', '动', '板', '尺', '換', '记', '让', '帅', '啇', '什', '纠', '膨', '貨', '翡', '诫', '训', '吸', '泰', 'y', '欢', '+', '夫', '咋', '嗯', '颜', '｀', '斤', '狗', '险', '链', '采', '灵', '讲', '沪', '哨', '挪', '券', 'V', '哈', '讽', '临', '顶', '偿', '怀', '矮', '贯', '溜', '匹', '力', '奔', '声', '漂', '贪', '己', '恼', ...

# %%
# 制作字典列表，用在人机交互
word_dictionary = {word: i+1 for i, word in enumerate(vocabulary)}
inverse_word_dictionary = {i+1: word for i, word in enumerate(vocabulary)}

print(word_dictionary)
# Out:
# {'书': 1, '碰': 2, '暂': 3, '忍': 4, '捌': 5, '症': 6, '鉴': 7, '痛': 8, '余': 9, '恳': 10, '辑': 11, 'o': 12, '螺': 13, '拨': 14, '鸡': 15, '叔': 16, '微': 17, '\uf604': 18, '兴': 19, '联': 20, '尚': 21, '丰': 22, '淫': 23, '浊': 24, '图': 25, '鯨': 26, '呼': 27, '品': 28, '钱': 29, '值': 30, '鄙': 31, '赚': 32, '嚯': 33, '池': 34, '孔': 35, '注': 36, '炮': 37, '寿': 38, '高': 39, '卸': 40, '谁': 41, '服': 42, '铝': 43, '虾': 44, '载': 45, '绕': 46, '压': 47, '玫': 48, '挑': 49, '救': 50, '叭': 51, '刀': 52, '仇': 53, '食': 54, '黥': 55, '真': 56, '循': 57, '京': 58, '、': 59, '□': 60, '简': 61, '官': 62, '屋': 63, '优': 64, '暗': 65, '蛮': 66, '禁': 67, '阜': 68, '犊': 69, '息': 70, '习': 71, '竞': 72, '啥': 73, '悄': 74, '闲': 75, '学': 76, '进': 77, '悠': 78, '甲': 79, '华': 80, '爱': 81, '娴': 82, 'N': 83, '氛': 84, '踪': 85, '柄': 86, '哩': 87, '继': 88, '借': 89, '”': 90, '木': 91, '噢': 92, '厌': 93, '感': 94, '薄': 95, '够': 96, '诉': 97
, 'I': 322, '改': 323, '前': 324, '千': 325, '摩': 326, '舌': 327, '宅': 328, '幕': 329, '全': 330, '點': 331, '壹': 332, '栽': 333, '正': 334, '福': 335, '不': 336, '叙': 337, '婆': 338, '怏': 339, '购': 340, '產': 341, '丢': 342, '呢': 343, '科': 344, '点': 345, '模': 346, '王': 347, '窗': 348, '望': 349, '考': 350, '呦': 351, '突': 352, '廉': 353, '峰': 354, '-': 355, '射': 356, '责': 357, '早': 358, '做': 359, '克': 360, '置': 361, '回': 362, '刑': 363, '抚': 364, '艾': 365, '瑰': 366, '赶': 367, '为': 368, '撰': 369, '降': 370, '起': 371, '忠': 372, '奏': 373, '详': 374, '他': 375, '哪': 376, '口': 377, '吵': 378, '灰': 379, '娃': 380, '城': 381, '泥': 382, '居': 383, '困': 384, '病': 385, '以': 386, '捷': 387, '尔': 388, '售': 389, '舒': 390, '非': 391, '粥': 392, '忑': 393, '户': 394, 'W': 395, '佰': 396, '季': 397, '~': 398, '列': 399, '怪': 400, '４': 401, '坛': 402, '班': 403, '尝': 404, '际': 405, '普': 406, '安': 407, '末': 408, '浓': 409, '剔': 41 ...
# {1: '书', 2: '碰', 3: '暂', 4: '忍', 5: '捌', 6: '症', 7: '鉴', 8: '痛', 9: '余', 10: '恳', 11: '辑', 12: 'o', 13: '螺', 14: '拨', 15: '鸡', 16: '叔', 17: '微', 18: '\uf604', 19: '兴', 20: '联', 21: '尚', 22: '丰', 23: '淫', 24: '浊', 25: '图', 26: '鯨', 27: '呼', 28: '品', 29: '钱', 30: '值', 31: '鄙', 32: '赚', 33: '嚯', 34: '池', 35: '孔', 36: '注', 37: '炮', 38: '寿', 39: '高', 40: '卸', 41: '谁', 42: '服', 43: '铝', 44: '虾', 45: '载', 46: '绕', 47: '压', 48: '玫', 49: '挑', 50: '救', 51: '叭', 52: '刀', 53: '仇', 54: '食', 55: '黥', 56: '真', 57: '循', 58: '京', 59: '、', 60: '□', 61: '简', 62: '官', 63: '屋', 64: '优', 65: '暗', 66: '蛮', 67: '禁', 68: '阜', 69: '犊', 70: '息', 71: '习', 72: '竞', 73: '啥', 74: '悄', 75: '闲', 76: '学', 77: '进', 78: '悠', 79: '甲', 80: '华', 81: '爱', 82: '娴', 83: 'N', 84: '氛', 85: '踪', 86: '柄', 87: '哩', 88: '继', 89: '借', 90: '”', 91: '木', 92: '噢', 93: '厌', 94: '感', 95: '薄', 96: '够', 97: '诉', 98: '饭', 99: '浙', 100: '掌', 101: '尾', 102: '搁', 103: '崩', 104: '鹰', 105: '慌', 106: '^', 107: '原', 108: '蒸', 109: '吗', 110: '博', 111: '开', 112: '日', 113: '洞', 114: '炒', 115: '刷', 116: '钟', 117: '凑', 118: '媒', 119: '影', 120: '示', 121: '软', 122: "'", 123: '>', 124: '骨', 125: '残', 126: '，', 127: '虑', 128: '绿', 129: '屎', 130: '统', 131: '糟', 132: '跤', 133: '爸', 134: '南', 135: '扎', 
', 362: '回', 363: '刑', 364: '抚', 365: '艾', 366: '瑰', 367: '赶', 368: '为', 369: '撰', 370: '降', 371: '起', 372: '忠', 373: '奏', 374: '详', 375: '他', 376: '哪', 377: '口', 378: '吵', 379: '灰', 380: '娃', 381: '城', 382: '泥', 383: '居', 384: '困', 385: '病', 386: '以', 387: '捷', 388: '尔', 389: '售', 390: '舒', 391: '非', 392: '粥', 393: '忑', 394: '户', 395: 'W', 396: '佰', 397: '季', 398: '~', 399: '列', 400: '怪', 401: '４', 402: '坛', 403: '班', 404: '尝', 405: '际', 406: '普', 407: '安', 408: '末', 409: '浓', 410: '剔 ...
# {'正面': 0, '负面': 1}
# {0: '正面', 1: '负面'}

# %%
print(inverse_word_dictionary)
# Out:
# {1: '书', 2: '碰', 3: '暂', 4: '忍', 5: '捌', 6: '症', 7: '鉴', 8: '痛', 9: '余', 10: '恳', 11: '辑', 12: 'o', 13: '螺', 14: '拨', 15: '鸡', 16: '叔', 17: '微', 18: '\uf604', 19: '兴', 20: '联', 21: '尚', 22: '丰', 23: '淫', 24: '浊', 25: '图', 26: '鯨', 27: '呼', 28: '品', 29: '钱', 30: '值', 31: '鄙', 32: '赚', 33: '嚯', 34: '池', 35: '孔', 36: '注', 37: '炮', 38: '寿', 39: '高', 40: '卸', 41: '谁', 42: '服', 43: '铝', 44: '虾', 45: '载', 46: '绕', 47: '压', 48: '玫', 49: '挑', 50: '救', 51: '叭', 52: '刀', 53: '仇', 54: '食', 55: '黥', 56: '真', 57: '循', 58: '京', 59: '、', 60: '□', 61: '简', 62: '官', 63: '屋', 64: '优', 65: '暗', 66: '蛮', 67: '禁', 68: '阜', 69: '犊', 70: '息', 71: '习', 72: '竞', 73: '啥', 74: '悄', 75: '闲', 76: '学', 77: '进', 78: '悠', 79: '甲', 80: '华', 81: '爱', 82: '娴', 83: 'N', 84: '氛', 85: '踪', 86: '柄', 87: '哩', 88: '继', 89: '借', 90: '”', 91: '木', 92: '噢', 93: '厌', 94: '感', 95: '薄', 96: '够', 97: '诉', 98: '饭', 99: '浙', 100: '掌', 101: '尾', 102: '搁', 103: '崩', 104: '鹰', 105: '慌', 106: '^', 107: '原', 108: '蒸', 109: '吗', 110: '博', 111: '开', 112: '日', 113: '洞', 114: '炒', 115: '刷', 116: '钟', 117: '凑', 118: '媒', 119: '影', 120: '示', 121: '软', 122: "'", 123: '>', 124: '骨', 125: '残', 126: '，', 127: '虑', 128: '绿', 129: '屎', 130: '统', 131: '糟', 132: '跤', 133: '爸', 134: '南', 135: '扎', 136: '太', 137: '由', 138: '流', 139: '通', 140: '歌', 141: '挽', 142: '\uf61c', 143: '首', 144: '裂', 145: '》', 146: '执', 147: '同', 148: '翻', 149: '军', 150: '瘪', 151: '嘿', 152: '费', 153: '砂', 154: '蛋', 155: '弃', 156: 'm', 157: '碎', 158: '亏', 159: '单', 160: '江', 161: '淘', 162: '差', 163: '读', 164: '苹', 165: '壮', 166: '玻', 167: '最', 168: '懂', 169: '恰', 170: '讨', 171: '赢', 172: '人', 173: '瓦', 174: '烂', 175: '顺', 176: '凌', 177: '憾', 178: '用', 179: '捞', 180: '今', 181: '悍', 182: '阶', 183: '卓', 184: '业', 185: '较', 186: '搪', 187: '粒', 188: '干', 189: '午', 190: '飞', 191: '陋', 192: 'k', 193: '见', 194: '描', 195: '：', 196: '豪', 197: '交', 198: '孑', 199: '昏', 200: '礼', 201: '貌', 202: '尘', 203: '鸟', 204: '脸', 205: '⑨', 206: '佛', 207: '遇', 208: '手', 209: '节', 210: '媳', 211: '相', 212: '揉', 213: '再', 214: '宁', 215: '杜', 216: '副', 217: '浦', 218: '吓', 219: '罢', 220: '办', 221: '蓝', 222: '零', 223: '锈', 224: '钻', 225: 'U', 226: '停', 227: '绍', 228: '買', 229: '散', 230: '括', 231: '律', 232: '算', 233: '亮', 234: '羡', 235: '哦', 236: '掏', 237: '论', 238: '渡', 239: '7', 240: '定', 241: '波', 242: '纳', 243: '牌', 244: '拭', 245: '识', 246: '窝', 247: '虽', 248: 'q', 249: '贩', 250: '锅', 251: '壁', 252: '花', 253: '变', 254: '辫', 255: '杂', 256: '者', 257: '摇', 258: '双', 259: 'G', 260: '馈', 261: '仪', 262: 'E', 263: '授', 264: '技', 265: '它', 266: '工', 267: '稿', 268: '反', 269: '灯', 270: '框', 271: '致', 272: '化', 273: '掘', 274: '案', 275: '衔', 276: '快', 277: '愤', 278: '鹅', 279: 'g', 280: '闸', 281: '剧', 282: '络', 283: '秀', 284: '竖', 285: '烈', 286: '厂', 287: '適', 288: '与', 289: '层', 290: '洁', 291: '豫', 292: '荣', 293: '尽', 294: '暖', 295: '校', 296: '序', 297: '篮', 298: '秋', 299: '盛', 300: '晓', 301: '野', 302: '布', 303: '年', 304: '康', 305: '看', 306: '五', 307: '度', 308: '挺', 309: '迟', 310: '象', 311: '凡', 312: '可', 313: '村', 314: '<', 315: '主', 316: '糙', 317: '击', 318: '况', 319: '宝', 320: '掉', 321: '势', 322: 'I', 323: '改', 324: '前', 325: '千', 326: '摩', 327: '舌', 328: '宅', 329: '幕', 330: '全', 331: '點', 332: '壹', 333: '栽', 334: '正', 335: '福', 336: '不', 337: '叙', 338: '婆', 339: '怏', 340: '购', 341: '產', 342: '丢', 343: '呢', 344: '科', 345: '点', 346: '模', 347: '王', 348: '窗', 349: '望', 350: '考', 351: '呦', 352: '突', 353: '廉', 354: '峰', 355: '-', 356: '射', 357: '责', 358: '早', 359: '做', 360: '克', 361: '置', 362: '回', 363: '刑', 364: '抚', 365: '艾', 366: '瑰', 367: '赶', 368: '为', 369: '撰', 370: '降', 371: '起', 372: '忠', 373: '奏', 374: '详', 375: '他', 376: '哪', 377: '口', 378: '吵', 379: '灰', 380: '娃', 381: '城', 382: '泥', 383: '居', 384: '困', 385: '病', 386: '以', 387: '捷', 388: '尔', 389: '售', 390: '舒', 391: '非', 392: '粥', 393: '忑', 394: '户', 395: 'W', 396: '佰', 397: '季', 398: '~', 399: '列', 400: '怪', 401: '４', 402: '坛', 403: '班', 404: '尝', 405: '际', 406: '普', 407: '安', 408: '末', 409: '浓', 410: '剔 ...

# %%
# 查看词汇表大小和标签类别数量
label_dictionary = {label: i for i, label in enumerate(labels)}
output_dictionary = {i: labels for i, labels in enumerate(labels)}

print(label_dictionary)
print(output_dictionary)
# Out:
# {'正面': 0, '负面': 1}

# %%
vocab_size = len(word_dictionary.keys()) 
label_size = len(label_dictionary.keys()) 

print(vocab_size)
print(label_size)
# Out:
# 2154
# 2

# %%
#制作训练输入和训练标签
#对于训练输入要进行序列填充，按input_shape填充，长度不足的按0补充
x = [[word_dictionary[word] for word in sent] for sent in data['evaluation']]
x = pad_sequences(maxlen=180,truncating="pre", sequences=x, padding='post', value=0)

print(x.shape)
# Out:
# (4283, 180)

# %%
#对于训练目标进行ONE-HOT-CODING
y = [[label_dictionary[sent]] for sent in data['label']]
y = [np_utils.to_categorical(label, num_classes=label_size) for label in y]
y = np.array([list(_[0]) for _ in y])

print(y.shape)
# Out:
# (4283, 2)

# %%
# 拆分训练集和测试集

train_x, test_x, train_y, test_y = train_test_split(x, y, test_size = 0.1)

# %%
#搭建模型
model = Sequential()
model.add(Embedding(input_dim=vocab_size + 1, output_dim=20,
                        input_length=180, mask_zero=True))
model.add(LSTM(100))
model.add(Dropout(0.2))
model.add(Dense(label_size, activation='softmax'))

model.summary()
    
#编译模型
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From D:\Users\Anaconda3\envs\env_cv\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From D:\Users\Anaconda3\envs\env_cv\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 180, 20)           43100
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100)               48400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 202
# =================================================================
# Total params: 91,702
# Trainable params: 91,702
# Non-trainable params: 0
# _________________________________________________________________

# %%
#训练模型

model.fit(train_x, train_y, epochs=5, batch_size=32, validation_data=(test_x, test_y))
# Out:
# WARNING:tensorflow:From D:\Users\Anaconda3\envs\env_cv\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 3854 samples, validate on 429 samples
# Epoch 1/5
# 3854/3854 [==============================] - 17s 4ms/step - loss: 0.4538 - acc: 0.7974 - val_loss: 0.2636 - val_acc: 0.9138
# Epoch 2/5
# 3854/3854 [==============================] - 20s 5ms/step - loss: 0.2080 - acc: 0.9305 - val_loss: 0.2048 - val_acc: 0.9371
# Epoch 3/5
# 3854/3854 [==============================] - 20s 5ms/step - loss: 0.1797 - acc: 0.9419 - val_loss: 0.2173 - val_acc: 0.9207
# Epoch 4/5
# 3854/3854 [==============================] - 21s 5ms/step - loss: 0.1592 - acc: 0.9499 - val_loss: 0.3184 - val_acc: 0.9161
# Epoch 5/5
# 3854/3854 [==============================] - 20s 5ms/step - loss: 0.1381 - acc: 0.9590 - val_loss: 0.2399 - val_acc: 0.9254

# %%
#测试新的评论
sent = "不是特别好"
sent = "真棒"
#sent = "什么垃圾"


temp_x = [[word_dictionary[word] for word in sent]]
temp_x = pad_sequences(maxlen=180, sequences=temp_x, padding='post', value=0)


# 模型预测
y_predict = model.predict(temp_x)
print(output_dictionary[np.argmax(y_predict)])
# Out:
# 正面
